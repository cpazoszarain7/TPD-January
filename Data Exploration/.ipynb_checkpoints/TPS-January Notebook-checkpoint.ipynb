# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Import Datasets

# %%
#Train Dataset
train = pd.read_csv('../Resources/train.csv')
#Test Dataset
test = pd.read_csv('../Resources/test.csv')

# %%
train.head()
# Out:
#    row_id        date  country       store         product  num_sold
# 0       0  2015-01-01  Finland  KaggleMart      Kaggle Mug       329
# 1       1  2015-01-01  Finland  KaggleMart      Kaggle Hat       520
# 2       2  2015-01-01  Finland  KaggleMart  Kaggle Sticker       146
# 3       3  2015-01-01  Finland  KaggleRama      Kaggle Mug       572
# 4       4  2015-01-01  Finland  KaggleRama      Kaggle Hat       911

# %%
#Dataset Characteristics
print('The train dataset has '+ str(train.shape[0])+' rows and '+ str(train.shape[1])+' columns')
print('The test dataset has '+ str(test.shape[0])+' rows and '+ str(test.shape[1])+' columns')
# Out:
# The train dataset has 26298 rows and 6 columns
# The test dataset has 6570 rows and 5 columns

# %%
column_names = train.columns
countries = train.country.value_counts().index
stores = train.store.value_counts().index
products = train.iloc[:,4].value_counts().index

# %%
print('The dataset has '+ str(len(countries))+' countries and the names are:')
for i in countries:
    print('-'+i)
print('')
print('The dataset has '+ str(len(stores))+' stores and the names are:')
for i in stores:
    print('-'+i)
print('')
print('The dataset has '+ str(len(products))+' products and the names are:')
for i in products:
    print('-'+i)
# Out:
# The dataset has 3 countries and the names are:
# -Finland
# -Sweden
# -Norway
#
# The dataset has 2 stores and the names are:
# -KaggleMart
# -KaggleRama
#
# The dataset has 3 products and the names are:
# -Kaggle Sticker
# -Kaggle Mug
# -Kaggle Hat

# %%
#Get the range of dates
#Training data range
print('Training Data - Max Date',train.date.max())
print('Training Data - Min Date',train.date.min())
#Test data range
print('Training Data - Max Date',test.date.max())
print('Training Data - Min Date',test.date.min())
# Out:
# Training Data - Max Date 2018-12-31
# Training Data - Min Date 2015-01-01
# Training Data - Max Date 2019-12-31
# Training Data - Min Date 2019-01-01

# %% [markdown]
# NOTE: Goal is to forecast the upcoming year of sales (2019)

# %%
#Review Data Types
train.info(), test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26298 entries, 0 to 26297
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   row_id    26298 non-null  int64
#  1   date      26298 non-null  object
#  2   country   26298 non-null  object
#  3   store     26298 non-null  object
#  4   product   26298 non-null  object
#  5   num_sold  26298 non-null  int64
# dtypes: int64(2), object(4)
# memory usage: 1.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6570 entries, 0 to 6569
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   row_id   6570 non-null   int64
#  1   date     6570 non-null   object
#  2   country  6570 non-null   object
#  3   store    6570 non-null   object
#  4   product  6570 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 256.8+ KB
# (None, None)

# %%
#Date column needs to be converted into datetime format
train.date = pd.to_datetime(train.date)
test.date = pd.to_datetime(test.date)

# %% [markdown]
# # Exploratory Data Analysis

# %%
#Visualizing Sales By Product & Store
KS = train[train['product']=='Kaggle Sticker']
KM = train[train['product']=='Kaggle Mug']
KH = train[train['product']=='Kaggle Hat']

# Subplots
fig, axes = plt.subplots(3, 1, figsize=(12, 10))

# Lineplots
sns.lineplot(ax=axes[0], data=KS, x='date', y='num_sold', hue='store')
sns.lineplot(ax=axes[1], data=KM, x='date', y='num_sold', hue ='store')
sns.lineplot(ax=axes[2], data=KH, x='date', y='num_sold', hue='store')
# Out:
#   File "<ipython-input-74-a4dce963fcf0>", line 3
#     KM = train[train['product']=='Kaggle Mug')]
#                                              ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
#Visualizing Sales By Country
#For KaggleMart
KM = train[train['store']=='KaggleMart']
KR = train[train['store']=='KaggleRama']


# Subplots
fig, axes = plt.subplots(2, 1, figsize=(12, 10))

# Lineplots
ax1=sns.lineplot(ax=axes[0], data=KM, x='date', y='num_sold', hue='country')
ax2=sns.lineplot(ax=axes[1], data=KR, x='date', y='num_sold', hue='country')

# %%
plot1 = KM.groupby(['date','country']).agg(num_sold=('num_sold','sum'))
# # plt.plot(x=plot1.date,y=plot1.num_sold)

# %%
KR=train[train.store=='KaggleRama']
bb=KR.groupby(['date','country']).agg(num_sold=('num_sold','sum'))

# %%
KM
# Out:
#        row_id       date  country       store         product  num_sold
# 0           0 2015-01-01  Finland  KaggleMart      Kaggle Mug       329
# 1           1 2015-01-01  Finland  KaggleMart      Kaggle Hat       520
# 2           2 2015-01-01  Finland  KaggleMart  Kaggle Sticker       146
# 6           6 2015-01-01   Norway  KaggleMart      Kaggle Mug       526
# 7           7 2015-01-01   Norway  KaggleMart      Kaggle Hat       906
# ...       ...        ...      ...         ...             ...       ...
# 26287   26287 2018-12-31   Norway  KaggleMart      Kaggle Hat      1124
# 26288   26288 2018-12-31   Norway  KaggleMart  Kaggle Sticker       351
# 26292   26292 2018-12-31   Sweden  KaggleMart      Kaggle Mug       570
# 26293   26293 2018-12-31   Sweden  KaggleMart      Kaggle Hat       823
# 26294   26294 2018-12-31   Sweden  KaggleMart  Kaggle Sticker       250
#
# [13149 rows x 6 columns]

# %%
sns.lineplot(data=KM, x='date',y='num_sold')
# Out:
# <AxesSubplot:xlabel='date', ylabel='num_sold'>
